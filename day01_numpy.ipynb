# %%
import numpy as np

a = np.array([1, 2, 3, 4, 5])
print(a)
# Out:
# [1 2 3 4 5]

# %%
print(a[0])
print(a[-1])
# Out:
# 1
# 5

# %%
print(a + 10)
print(a * 2)
# Out:
# [11 12 13 14 15]
# [ 2  4  6  8 10]

# %%
print(np.sum(a))
print(np.mean(a))
print(np.max(a))
print(np.min(a))
# Out:
# 15
# 3.0
# 5
# 1

# %%
b = np.array([[1, 2, 3],
              [4, 5, 6]])
print(b)
print(b.shape)
# Out:
# [[1 2 3]
#  [4 5 6]]
# (2, 3)
