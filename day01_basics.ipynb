# %%
name = "Abhi"
age = 20
print(name)
print(age)
# Out:
# Abhi
# 20

# %%
marks = [85, 90, 78, 92]
print(marks[0])
print(marks[2])
# Out:
# 85
# 78

# %%
for mark in marks:
    print(mark)
# Out:
# 85
# 90
# 78
# 92

# %%
def add(a, b):
    return a + b

print(add(5, 10))
# Out:
# 15

# %%
score = 75
if score > 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass
